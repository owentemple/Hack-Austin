# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import pandas as pd
import numpy as np

# %%
def concatenate():
    # Create Super Dataset
    # From files downloaded from https://github.com/cityofaustin/hack-austin/tree/master/Austin%20Fire%20Department%20Data

    # 2012
    fire_2012 = pd.read_csv(os.path.join('..', 'AFD_CY12 - SOC Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2012.dropna(inplace=True)
    fire_2012.index = pd.to_datetime(fire_2012.index)

    # 2013
    fire_2013 = pd.read_csv(os.path.join('..', 'AFD_CY13 - SOC Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2013.dropna(inplace=True)
    fire_2013.index = pd.to_datetime(fire_2013.index)

    # 2014
    fire_2014 = pd.read_csv(os.path.join('..', 'AFD_CY14 - SOC Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2014.dropna(inplace=True)
    fire_2014.index = pd.to_datetime(fire_2014.index)

    # 2015
    fire_2015 = pd.read_csv(os.path.join('..', 'AFD_CY15 - SOC Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2015.dropna(inplace=True)
    fire_2015.index = pd.to_datetime(fire_2015.index)

    # 2016
    fire_2016 = pd.read_csv(os.path.join('..', 'AFD_CY16 - SOC Fire Data Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2016.dropna(inplace=True)
    fire_2016.index = pd.to_datetime(fire_2016.index)

    # 2017
    fire_2017 = pd.read_csv(os.path.join('..', 'AFD_CY17 - SOC Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2017.dropna(inplace=True)
    fire_2017.index = pd.to_datetime(fire_2017.index)

    # Combine all years into single dataframe
    final_df = pd.concat([fire_2012, fire_2013, fire_2014, fire_2015, fire_2016, fire_2017])

    # Calculate time between AFD phone pickup and first unit arrival in seconds and in minutes
    final_df['First Unit Arrived'] = pd.to_datetime(final_df['First Unit Arrived'])
    final_df['Response Time (s)'] = (final_df['First Unit Arrived'] - final_df.index).astype('timedelta64[s]')
    final_df['Response Time (m)'] = ((final_df['First Unit Arrived'] - final_df.index).astype('timedelta64[s]')) / 60
    final_df.reset_index(inplace=True)

    # Read in incident detail reports for all years available
    # Downloaded from https://data.austintexas.gov/browse?q=AFD&sortBy=relevance&anonymous=true
    AFD_13 = pd.read_csv(os.path.join('..', 'AFD_Fire_Incidents_2013_January_Thru_December.csv'))
    AFD_14 = pd.read_csv(os.path.join('..', 'AFD_Fire_Incidents_2014_January_Thru_December.csv'))
    AFD_15 = pd.read_csv(os.path.join('..', 'AFD_Fire_Incidents_2015_January_Thru_December.csv'))
    AFD_16 = pd.read_csv(os.path.join('..', 'AFD_Fire_Incidents_2016_January_Thru_December.csv'))

    # Concatenate all years incident detail reports into one dataframe
    frames = [AFD_13, AFD_14, AFD_15, AFD_16]
    result = pd.concat(frames)
    result = result.rename(index=str, columns={"MasterIncidentNumber": "Master Incident Number"})

    # Join dataframe with response time information with problem detail dataframe
    detail_final_df = pd.merge(final_df, result, how='inner', on='Master Incident Number')
    detail_final_df['day_of_week'] = detail_final_df['First Unit Arrived'].dt.dayofweek
    detail_final_df['hour'] = detail_final_df['First Unit Arrived'].dt.hour
    detail_final_df['late_response'] = np.where(detail_final_df['Response Time (s)'] > (60 * 8), 1, 0)

    del detail_final_df['CalendarYear_y']
    del detail_final_df['PriorityDescription_y']
    del detail_final_df['Response Status_y']
    detail_final_df.rename(columns={'CalendarYear_x': 'CalendarYear', 'Response Status_x': 'Response Status',
                                    'PriorityDescription_x': 'PriorityDescription'}, inplace=True)

    detail_final_df.to_csv(os.path.join('..', 'All Years with Response Times and Problem Types.csv'))
    return detail_final_df

# %%
df = concatenate()

# %%
df.head()
# Out:
#   AFD Time Phone Pickup  Master Incident Number  CalendarYear  \
# 0   2013-01-01 00:08:18                13000006          2013
# 1   2013-01-01 00:37:29                13000016          2013
# 2   2013-01-01 17:00:25                13000263          2013
# 3   2013-01-01 18:42:02                13000281          2013
# 4   2013-01-01 19:21:55                13000291          2013
#
#   Cancellation Status General Dispatched Problem   \
# 0       Not Cancelled                        Fire
# 1       Not Cancelled                        Fire
# 2       Not Cancelled                        Fire
# 3       Not Cancelled                        Fire
# 4       Not Cancelled                        Fire
#
#   Calltaker Agency (AFD or EMS) Order of AFD Arrival Response Area (COA Only)  \
# 0                           AFD      1st or Only AFD                  00-3001
# 1                           AFD      1st or Only AFD                  00-2205
# 2                           AFD      1st or Only AFD                  00-2402
# 3                           AFD      1st or Only AFD                  00-0701
# 4                           AFD      1st or Only AFD                  00-2201
#
#   First Arriving Unit Name Response Status      ...      Call_Type  \
# 0                    ENG23          Code 3      ...           Fire
# 1                    ENG22          Code 3      ...           Fire
# 2                    ENG24          Code 3      ...           Fire
# 3                    ENG07          Code 3      ...           Fire
# 4                    ENG22          Code 3      ...           Fire
#
#                 Problem Battalion Jurisdiction ResponseArea Districts  \
# 0    TRASH - Trash Fire        B3          AFD      00-3001         -
# 1    TRASH - Trash Fire        B5          AFD      00-2205         -
# 2  BOXL- Structure Fire        B5          AFD      00-2402         -
# 3    TRASH - Trash Fire        B5          AFD      00-0701         -
# 4      AUTO - Auto Fire        B5          AFD      00-2201         -
#
#              Location 1  day_of_week hour late_response
# 0  (30368606, 97697237)            1    0             1
# 1  (30222548, 97695303)            1    0             0
# 2  (30204730, 97756601)            1   17             0
# 3  (30251905, 97727779)            1   18             0
# 4  (30230773, 97721155)            1   19             0
#
# [5 rows x 34 columns]

# %%
## Use Random Forest to find important features in 2016

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
my_columns = list(df_dummies.columns)

# %%
my_columns
# Out:
# ['AFD Time Phone Pickup',
#  'Master Incident Number',
#  'CalendarYear',
#  'Cancellation Status',
#  'General Dispatched Problem ',
#  'Calltaker Agency (AFD or EMS)',
#  'Order of AFD Arrival',
#  'Response Area (COA Only)',
#  'First Arriving Unit Name',
#  'Response Status',
#  'PriorityDescription',
#  'EMS Time Phone Pickup',
#  'Earliest Time Phone Pickup',
#  'First Unit Assigned',
#  'Did not Reduce to Code 1',
#  'Onscene Time Was Correct',
#  'Latitude',
#  'Longitude',
#  'First Unit Enroute',
#  'First Unit Arrived',
#  'Response Time (s)',
#  'Response Time (m)',
#  'Month',
#  'DayOfMonth',
#  'Call_Type',
#  'Battalion',
#  'Jurisdiction',
#  'Districts',
#  'Location 1',
#  'late_response',
#  'Problem_AUTO - Auto Fire',
#  'Problem_BBQ - Unsafe Cooking',
#  'Problem_BOX -Structure Fire',
#  'Problem_BOXL- Structure Fire',
#  'Problem_BRSHL - Brush Alarm / Light',
#  'Problem_DUMP - Dumpster Fire',
#  'Problem_ELEC - Electrical Fire',
#  'Problem_GRASS - Small Grass Fire',
#  'Problem_TRASH - Trash Fire',
#  'ResponseArea_00-0040',
#  'ResponseArea_00-0060',
#  'ResponseArea_00-0070',
#  'ResponseArea_00-0101',
#  'ResponseArea_00-0102',
#  'ResponseArea_00-0201',
#  'ResponseArea_00-0202',
#  'ResponseArea_00-0203',
#  'ResponseArea_00-0301',
#  'ResponseArea_00-0302',
#  'ResponseArea_00-0303',
#  'ResponseArea_00-0401',
#  'ResponseArea_00-0402',
#  'ResponseArea_00-0501',
#  'ResponseArea_00-0502',
#  'ResponseArea_00-0503',
#  'ResponseArea_00-0504',
#  'ResponseArea_00-0505',
#  'ResponseArea_00-0601',
#  'ResponseArea_00-0602',
#  'ResponseArea_00-0603',
#  'ResponseArea_00-0604',
#  'ResponseArea_00-0701',
#  'ResponseArea_00-0702',
#  'ResponseArea_00-0801',
#  'ResponseArea_00-0802',
#  'ResponseArea_00-0803',
#  'ResponseArea_00-0804',
#  'ResponseArea_00-0805',
#  'ResponseArea_00-0806',
#  'ResponseArea_00-0807',
#  'ResponseArea_00-0901',
#  'ResponseArea_00-0902',
#  'ResponseArea_00-0903',
#  'ResponseArea_00-1001',
#  'ResponseArea_00-1002',
#  'ResponseArea_00-1003',
#  'ResponseArea_00-1101',
#  'ResponseArea_00-1102',
#  'ResponseArea_00-1103',
#  'ResponseArea_00-1104',
#  'ResponseArea_00-1201',
#  'ResponseArea_00-1202',
#  'ResponseArea_00-1203',
#  'ResponseArea_00-1204',
#  'ResponseArea_00-1205',
#  'ResponseArea_00-1206',
#  'ResponseArea_00-1401',
#  'ResponseArea_00-1402',
#  'ResponseArea_00-1403',
#  'ResponseArea_00-1404',
#  'ResponseArea_00-1405',
#  'ResponseArea_00-1406',
#  'ResponseArea_00-1407',
#  'ResponseArea_00-1501',
#  'ResponseArea_00-1502',
#  'ResponseArea_00-1503',
#  'ResponseArea_00-1504',
#  'ResponseArea_00-1505',
#  'ResponseArea_00-1601',
#  'ResponseArea_00-1602',
#  'ResponseArea_00-1603',
#  'ResponseArea_00-1604',
#  'ResponseArea_00-1605',
#  'ResponseArea_00-1606',
#  'ResponseArea_00-1701',
#  'ResponseArea_00-1702',
#  'ResponseArea_00-1703',
#  'ResponseArea_00-1704',
#  'ResponseArea_00-1705',
#  'ResponseArea_00-1706',
#  'ResponseArea_00-1707',
#  'ResponseArea_00-1708',
#  'ResponseArea_00-1709',
#  'ResponseArea_00-1710',
#  'ResponseArea_00-1712',
#  'ResponseArea_00-17SV',
#  'ResponseArea_00-1801',
#  'ResponseArea_00-1802',
#  'ResponseArea_00-1803',
#  'ResponseArea_00-1804',
#  'ResponseArea_00-1805',
#  'ResponseArea_00-1901',
#  'ResponseArea_00-1902',
#  'ResponseArea_00-1903',
#  'ResponseArea_00-1904',
#  'ResponseArea_00-1905',
#  'ResponseArea_00-2001',
#  'ResponseArea_00-2002',
#  'ResponseArea_00-2003',
#  'ResponseArea_00-2004',
#  'ResponseArea_00-2005',
#  'ResponseArea_00-2006',
#  'ResponseArea_00-2101',
#  'ResponseArea_00-2102',
#  'ResponseArea_00-2103',
#  'ResponseArea_00-2104',
#  'ResponseArea_00-2201',
#  'ResponseArea_00-2202',
#  'ResponseArea_00-2203',
#  'ResponseArea_00-2204',
#  'ResponseArea_00-2205',
#  'ResponseArea_00-2206',
#  'ResponseArea_00-2301',
#  'ResponseArea_00-2302',
#  'ResponseArea_00-2303',
#  'ResponseArea_00-2304',
#  'ResponseArea_00-2305',
#  'ResponseArea_00-2306',
#  'ResponseArea_00-2401',
#  'ResponseArea_00-2402',
#  'ResponseArea_00-2403',
#  'ResponseArea_00-2404',
#  'ResponseArea_00-2501',
#  'ResponseArea_00-2502',
#  'ResponseArea_00-2503',
#  'ResponseArea_00-2504',
#  'ResponseArea_00-2601',
#  'ResponseArea_00-2604',
#  'ResponseArea_00-2605',
#  'ResponseArea_00-2606',
#  'ResponseArea_00-2607',
#  'ResponseArea_00-2608',
#  'ResponseArea_00-2610',
#  'ResponseArea_00-2611',
#  'ResponseArea_00-2701',
#  'ResponseArea_00-2702',
#  'ResponseArea_00-2703',
#  'ResponseArea_00-2704',
#  'ResponseArea_00-2705',
#  'ResponseArea_00-2706',
#  'ResponseArea_00-27SV',
#  'ResponseArea_00-2801',
#  'ResponseArea_00-2803',
#  'ResponseArea_00-2804',
#  'ResponseArea_00-2805',
#  'ResponseArea_00-2806',
#  'ResponseArea_00-2807',
#  'ResponseArea_00-2808',
#  'ResponseArea_00-2901',
#  'ResponseArea_00-2902',
#  'ResponseArea_00-2903',
#  'ResponseArea_00-2904',
#  'ResponseArea_00-2905',
#  'ResponseArea_00-2906',
#  'ResponseArea_00-2907',
#  'ResponseArea_00-2910',
#  'ResponseArea_00-3001',
#  'ResponseArea_00-3002',
#  'ResponseArea_00-3003',
#  'ResponseArea_00-3004',
#  'ResponseArea_00-3005',
#  'ResponseArea_00-3101',
#  'ResponseArea_00-3102',
#  'ResponseArea_00-3103',
#  'ResponseArea_00-3104',
#  'ResponseArea_00-3105',
#  'ResponseArea_00-3106',
#  'ResponseArea_00-3107',
#  'ResponseArea_00-3201',
#  'ResponseArea_00-3202',
#  'ResponseArea_00-3203',
#  'ResponseArea_00-3204',
#  'ResponseArea_00-3205',
#  'ResponseArea_00-3207',
#  'ResponseArea_00-3209',
#  'ResponseArea_00-3301',
#  'ResponseArea_00-3303',
#  'ResponseArea_00-3304',
#  'ResponseArea_00-3400',
#  'ResponseArea_00-3401',
#  'ResponseArea_00-3402',
#  'ResponseArea_00-3403',
#  'ResponseArea_00-3404',
#  'ResponseArea_00-3501',
#  'ResponseArea_00-3502',
#  'ResponseArea_00-3503',
#  'ResponseArea_00-3504',
#  'ResponseArea_00-3505',
#  'ResponseArea_00-3507',
#  'ResponseArea_00-3508',
#  'ResponseArea_00-3601',
#  'ResponseArea_00-3602',
#  'ResponseArea_00-3603',
#  'ResponseArea_00-3604',
#  'ResponseArea_00-3605',
#  'ResponseArea_00-3606',
#  'ResponseArea_00-3607',
#  'ResponseArea_00-3608',
#  'ResponseArea_00-3610',
#  'ResponseArea_00-3611',
#  'ResponseArea_00-3701',
#  'ResponseArea_00-3702',
#  'ResponseArea_00-3703',
#  'ResponseArea_00-3801',
#  'ResponseArea_00-3802',
#  'ResponseArea_00-3804',
#  'ResponseArea_00-3808',
#  'ResponseArea_00-3809',
#  'ResponseArea_00-3810',
#  'ResponseArea_00-3901',
#  'ResponseArea_00-3902',
#  'ResponseArea_00-3904',
#  'ResponseArea_00-3906',
#  'ResponseArea_00-3907',
#  'ResponseArea_00-3908',
#  'ResponseArea_00-4001',
#  'ResponseArea_00-4002',
#  'ResponseArea_00-4003',
#  'ResponseArea_00-4004',
#  'ResponseArea_00-4005',
#  'ResponseArea_00-4006',
#  'ResponseArea_00-4101',
#  'ResponseArea_00-4102',
#  'ResponseArea_00-4103',
#  'ResponseArea_00-4104',
#  'ResponseArea_00-4105',
#  'ResponseArea_00-4107',
#  'ResponseArea_00-4108',
#  'ResponseArea_00-4201',
#  'ResponseArea_00-4202',
#  'ResponseArea_00-4203',
#  'ResponseArea_00-4204',
#  'ResponseArea_00-4205',
#  'ResponseArea_00-4209',
#  'ResponseArea_00-4210',
#  'ResponseArea_00-4301',
#  'ResponseArea_00-4302',
#  'ResponseArea_00-4303',
#  'ResponseArea_00-4305',
#  'ResponseArea_00-4401',
#  'ResponseArea_00-4402',
#  'ResponseArea_00-4403',
#  'ResponseArea_00-4404',
#  'ResponseArea_00-4405',
#  'ResponseArea_00-4501',
#  'ResponseArea_00-4502',
#  'ResponseArea_00-4503',
#  'ResponseArea_00-4504',
#  'ResponseArea_00-4505',
#  'ResponseArea_00-4506',
#  'day_of_week_0',
#  'day_of_week_1',
#  'day_of_week_2',
#  'day_of_week_3',
#  'day_of_week_4',
#  'day_of_week_5',
#  'day_of_week_6',
#  'hour_0',
#  'hour_1',
#  'hour_2',
#  'hour_3',
#  'hour_4',
#  'hour_5',
#  'hour_6',
#  'hour_7',
#  'hour_8',
#  'hour_9',
#  'hour_10',
#  'hour_11',
#  'hour_12',
#  'hour_13',
#  'hour_14',
#  'hour_15',
#  'hour_16',
#  'hour_17',
#  'hour_18',
#  'hour_19',
#  'hour_20',
#  'hour_21',
#  'hour_22',
#  'hour_23']

# %%
df_2016 = df[df['CalendarYear'] >= 2016]

# %%
df_dummies_2016 = pd.get_dummies(df_2016, columns=['Problem', 'ResponseArea', 'day_of_week', 'hour'])

# %%
df_dummies_2016.head()
# Out:
#      AFD Time Phone Pickup  Master Incident Number  CalendarYear  \
# 5744   2016-01-01 00:34:56                16000015          2016
# 5745   2016-01-01 02:04:57                16000045          2016
# 5746   2016-01-01 10:59:44                16000165          2016
# 5747   2016-01-01 12:25:08                16000184          2016
# 5748   2016-01-01 12:36:12                16000188          2016
#
#        Cancellation Status General Dispatched Problem   \
# 5744  Cancelled On Arrival                        Fire
# 5745         Not Cancelled                        Fire
# 5746         Not Cancelled                        Fire
# 5747         Not Cancelled                        Fire
# 5748         Not Cancelled                        Fire
#
#      Calltaker Agency (AFD or EMS) Order of AFD Arrival  \
# 5744                           AFD      1st or Only AFD
# 5745                           AFD      1st or Only AFD
# 5746                           AFD      1st or Only AFD
# 5747                           AFD      1st or Only AFD
# 5748                           AFD      1st or Only AFD
#
#      Response Area (COA Only) First Arriving Unit Name Response Status  \
# 5744                  00-2004                    ENG20          Code 3
# 5745                  00-1801                    ENG18          Code 3
# 5746                  00-4001                    ENG40          Code 3
# 5747                  00-3001                    ENG30          Code 3
# 5748                  00-0804                    ENG08          Code 3
#
#        ...   hour_14 hour_15 hour_16 hour_17 hour_18 hour_19  hour_20  \
# 5744   ...         0       0       0       0       0       0        0
# 5745   ...         0       0       0       0       0       0        0
# 5746   ...         0       0       0       0       0       0        0
# 5747   ...         0       0       0       0       0       0        0
# 5748   ...         0       0       0       0       0       0        0
#
#       hour_21 hour_22 hour_23
# 5744        0       0       0
# 5745        0       0       0
# 5746        0       0       0
# 5747        0       0       0
# 5748        0       0       0
#
# [5 rows x 234 columns]

# %%
my_columns = list(df_dummies_2016.columns)

# %%
my_columns
# Out:
# ['AFD Time Phone Pickup',
#  'Master Incident Number',
#  'CalendarYear',
#  'Cancellation Status',
#  'General Dispatched Problem ',
#  'Calltaker Agency (AFD or EMS)',
#  'Order of AFD Arrival',
#  'Response Area (COA Only)',
#  'First Arriving Unit Name',
#  'Response Status',
#  'PriorityDescription',
#  'EMS Time Phone Pickup',
#  'Earliest Time Phone Pickup',
#  'First Unit Assigned',
#  'Did not Reduce to Code 1',
#  'Onscene Time Was Correct',
#  'Latitude',
#  'Longitude',
#  'First Unit Enroute',
#  'First Unit Arrived',
#  'Response Time (s)',
#  'Response Time (m)',
#  'Month',
#  'DayOfMonth',
#  'Call_Type',
#  'Battalion',
#  'Jurisdiction',
#  'Districts',
#  'Location 1',
#  'late_response',
#  'Problem_AUTO - Auto Fire',
#  'Problem_BBQ - Unsafe Cooking',
#  'Problem_BOXL- Structure Fire',
#  'Problem_BRSHL - Brush Alarm / Light',
#  'Problem_DUMP - Dumpster Fire',
#  'Problem_ELEC - Electrical Fire',
#  'Problem_GRASS - Small Grass Fire',
#  'Problem_TRASH - Trash Fire',
#  'ResponseArea_00-0101',
#  'ResponseArea_00-0102',
#  'ResponseArea_00-0201',
#  'ResponseArea_00-0202',
#  'ResponseArea_00-0203',
#  'ResponseArea_00-0301',
#  'ResponseArea_00-0303',
#  'ResponseArea_00-0401',
#  'ResponseArea_00-0501',
#  'ResponseArea_00-0502',
#  'ResponseArea_00-0503',
#  'ResponseArea_00-0504',
#  'ResponseArea_00-0505',
#  'ResponseArea_00-0601',
#  'ResponseArea_00-0602',
#  'ResponseArea_00-0603',
#  'ResponseArea_00-0604',
#  'ResponseArea_00-0701',
#  'ResponseArea_00-0702',
#  'ResponseArea_00-0801',
#  'ResponseArea_00-0802',
#  'ResponseArea_00-0803',
#  'ResponseArea_00-0804',
#  'ResponseArea_00-0805',
#  'ResponseArea_00-0806',
#  'ResponseArea_00-0807',
#  'ResponseArea_00-0902',
#  'ResponseArea_00-0903',
#  'ResponseArea_00-1001',
#  'ResponseArea_00-1002',
#  'ResponseArea_00-1003',
#  'ResponseArea_00-1101',
#  'ResponseArea_00-1102',
#  'ResponseArea_00-1103',
#  'ResponseArea_00-1104',
#  'ResponseArea_00-1201',
#  'ResponseArea_00-1202',
#  'ResponseArea_00-1204',
#  'ResponseArea_00-1205',
#  'ResponseArea_00-1206',
#  'ResponseArea_00-1401',
#  'ResponseArea_00-1403',
#  'ResponseArea_00-1404',
#  'ResponseArea_00-1405',
#  'ResponseArea_00-1501',
#  'ResponseArea_00-1504',
#  'ResponseArea_00-1505',
#  'ResponseArea_00-1601',
#  'ResponseArea_00-1602',
#  'ResponseArea_00-1603',
#  'ResponseArea_00-1604',
#  'ResponseArea_00-1605',
#  'ResponseArea_00-1606',
#  'ResponseArea_00-1701',
#  'ResponseArea_00-1703',
#  'ResponseArea_00-1705',
#  'ResponseArea_00-1706',
#  'ResponseArea_00-1707',
#  'ResponseArea_00-1708',
#  'ResponseArea_00-1709',
#  'ResponseArea_00-1710',
#  'ResponseArea_00-1712',
#  'ResponseArea_00-1801',
#  'ResponseArea_00-1802',
#  'ResponseArea_00-1803',
#  'ResponseArea_00-1804',
#  'ResponseArea_00-1805',
#  'ResponseArea_00-1901',
#  'ResponseArea_00-1903',
#  'ResponseArea_00-2001',
#  'ResponseArea_00-2002',
#  'ResponseArea_00-2004',
#  'ResponseArea_00-2005',
#  'ResponseArea_00-2006',
#  'ResponseArea_00-2101',
#  'ResponseArea_00-2102',
#  'ResponseArea_00-2103',
#  'ResponseArea_00-2104',
#  'ResponseArea_00-2201',
#  'ResponseArea_00-2202',
#  'ResponseArea_00-2203',
#  'ResponseArea_00-2204',
#  'ResponseArea_00-2205',
#  'ResponseArea_00-2206',
#  'ResponseArea_00-2301',
#  'ResponseArea_00-2303',
#  'ResponseArea_00-2304',
#  'ResponseArea_00-2305',
#  'ResponseArea_00-2306',
#  'ResponseArea_00-2401',
#  'ResponseArea_00-2402',
#  'ResponseArea_00-2403',
#  'ResponseArea_00-2404',
#  'ResponseArea_00-2501',
#  'ResponseArea_00-2502',
#  'ResponseArea_00-2504',
#  'ResponseArea_00-2601',
#  'ResponseArea_00-2606',
#  'ResponseArea_00-2607',
#  'ResponseArea_00-2608',
#  'ResponseArea_00-2701',
#  'ResponseArea_00-2704',
#  'ResponseArea_00-2705',
#  'ResponseArea_00-2706',
#  'ResponseArea_00-27SV',
#  'ResponseArea_00-2801',
#  'ResponseArea_00-2803',
#  'ResponseArea_00-2804',
#  'ResponseArea_00-2805',
#  'ResponseArea_00-2806',
#  'ResponseArea_00-2808',
#  'ResponseArea_00-2901',
#  'ResponseArea_00-2902',
#  'ResponseArea_00-2903',
#  'ResponseArea_00-2904',
#  'ResponseArea_00-3001',
#  'ResponseArea_00-3002',
#  'ResponseArea_00-3003',
#  'ResponseArea_00-3004',
#  'ResponseArea_00-3005',
#  'ResponseArea_00-3102',
#  'ResponseArea_00-3105',
#  'ResponseArea_00-3106',
#  'ResponseArea_00-3201',
#  'ResponseArea_00-3203',
#  'ResponseArea_00-3209',
#  'ResponseArea_00-3303',
#  'ResponseArea_00-3304',
#  'ResponseArea_00-3401',
#  'ResponseArea_00-3403',
#  'ResponseArea_00-3404',
#  'ResponseArea_00-3501',
#  'ResponseArea_00-3502',
#  'ResponseArea_00-3503',
#  'ResponseArea_00-3504',
#  'ResponseArea_00-3601',
#  'ResponseArea_00-3602',
#  'ResponseArea_00-3603',
#  'ResponseArea_00-3604',
#  'ResponseArea_00-3606',
#  'ResponseArea_00-3607',
#  'ResponseArea_00-3608',
#  'ResponseArea_00-3611',
#  'ResponseArea_00-3802',
#  'ResponseArea_00-3808',
#  'ResponseArea_00-3809',
#  'ResponseArea_00-3810',
#  'ResponseArea_00-3901',
#  'ResponseArea_00-3906',
#  'ResponseArea_00-3907',
#  'ResponseArea_00-3908',
#  'ResponseArea_00-4001',
#  'ResponseArea_00-4002',
#  'ResponseArea_00-4003',
#  'ResponseArea_00-4004',
#  'ResponseArea_00-4005',
#  'ResponseArea_00-4101',
#  'ResponseArea_00-4103',
#  'ResponseArea_00-4105',
#  'ResponseArea_00-4201',
#  'ResponseArea_00-4209',
#  'ResponseArea_00-4302',
#  'ResponseArea_00-4401',
#  'ResponseArea_00-4502',
#  'ResponseArea_00-4504',
#  'day_of_week_0',
#  'day_of_week_1',
#  'day_of_week_2',
#  'day_of_week_3',
#  'day_of_week_4',
#  'day_of_week_5',
#  'day_of_week_6',
#  'hour_0',
#  'hour_1',
#  'hour_2',
#  'hour_3',
#  'hour_4',
#  'hour_5',
#  'hour_6',
#  'hour_7',
#  'hour_8',
#  'hour_9',
#  'hour_10',
#  'hour_11',
#  'hour_12',
#  'hour_13',
#  'hour_14',
#  'hour_15',
#  'hour_16',
#  'hour_17',
#  'hour_18',
#  'hour_19',
#  'hour_20',
#  'hour_21',
#  'hour_22',
#  'hour_23']

# %%
features = [
 'Problem_AUTO - Auto Fire',
 'Problem_BBQ - Unsafe Cooking',
 'Problem_BOXL- Structure Fire',
 'Problem_BRSHL - Brush Alarm / Light',
 'Problem_DUMP - Dumpster Fire',
 'Problem_ELEC - Electrical Fire',
 'Problem_GRASS - Small Grass Fire',
 'Problem_TRASH - Trash Fire',
 'ResponseArea_00-0101',
 'ResponseArea_00-0102',
 'ResponseArea_00-0201',
 'ResponseArea_00-0202',
 'ResponseArea_00-0203',
 'ResponseArea_00-0301',
 'ResponseArea_00-0303',
 'ResponseArea_00-0401',
 'ResponseArea_00-0501',
 'ResponseArea_00-0502',
 'ResponseArea_00-0503',
 'ResponseArea_00-0504',
 'ResponseArea_00-0505',
 'ResponseArea_00-0601',
 'ResponseArea_00-0602',
 'ResponseArea_00-0603',
 'ResponseArea_00-0604',
 'ResponseArea_00-0701',
 'ResponseArea_00-0702',
 'ResponseArea_00-0801',
 'ResponseArea_00-0802',
 'ResponseArea_00-0803',
 'ResponseArea_00-0804',
 'ResponseArea_00-0805',
 'ResponseArea_00-0806',
 'ResponseArea_00-0807',
 'ResponseArea_00-0902',
 'ResponseArea_00-0903',
 'ResponseArea_00-1001',
 'ResponseArea_00-1002',
 'ResponseArea_00-1003',
 'ResponseArea_00-1101',
 'ResponseArea_00-1102',
 'ResponseArea_00-1103',
 'ResponseArea_00-1104',
 'ResponseArea_00-1201',
 'ResponseArea_00-1202',
 'ResponseArea_00-1204',
 'ResponseArea_00-1205',
 'ResponseArea_00-1206',
 'ResponseArea_00-1401',
 'ResponseArea_00-1403',
 'ResponseArea_00-1404',
 'ResponseArea_00-1405',
 'ResponseArea_00-1501',
 'ResponseArea_00-1504',
 'ResponseArea_00-1505',
 'ResponseArea_00-1601',
 'ResponseArea_00-1602',
 'ResponseArea_00-1603',
 'ResponseArea_00-1604',
 'ResponseArea_00-1605',
 'ResponseArea_00-1606',
 'ResponseArea_00-1701',
 'ResponseArea_00-1703',
 'ResponseArea_00-1705',
 'ResponseArea_00-1706',
 'ResponseArea_00-1707',
 'ResponseArea_00-1708',
 'ResponseArea_00-1709',
 'ResponseArea_00-1710',
 'ResponseArea_00-1712',
 'ResponseArea_00-1801',
 'ResponseArea_00-1802',
 'ResponseArea_00-1803',
 'ResponseArea_00-1804',
 'ResponseArea_00-1805',
 'ResponseArea_00-1901',
 'ResponseArea_00-1903',
 'ResponseArea_00-2001',
 'ResponseArea_00-2002',
 'ResponseArea_00-2004',
 'ResponseArea_00-2005',
 'ResponseArea_00-2006',
 'ResponseArea_00-2101',
 'ResponseArea_00-2102',
 'ResponseArea_00-2103',
 'ResponseArea_00-2104',
 'ResponseArea_00-2201',
 'ResponseArea_00-2202',
 'ResponseArea_00-2203',
 'ResponseArea_00-2204',
 'ResponseArea_00-2205',
 'ResponseArea_00-2206',
 'ResponseArea_00-2301',
 'ResponseArea_00-2303',
 'ResponseArea_00-2304',
 'ResponseArea_00-2305',
 'ResponseArea_00-2306',
 'ResponseArea_00-2401',
 'ResponseArea_00-2402',
 'ResponseArea_00-2403',
 'ResponseArea_00-2404',
 'ResponseArea_00-2501',
 'ResponseArea_00-2502',
 'ResponseArea_00-2504',
 'ResponseArea_00-2601',
 'ResponseArea_00-2606',
 'ResponseArea_00-2607',
 'ResponseArea_00-2608',
 'ResponseArea_00-2701',
 'ResponseArea_00-2704',
 'ResponseArea_00-2705',
 'ResponseArea_00-2706',
 'ResponseArea_00-27SV',
 'ResponseArea_00-2801',
 'ResponseArea_00-2803',
 'ResponseArea_00-2804',
 'ResponseArea_00-2805',
 'ResponseArea_00-2806',
 'ResponseArea_00-2808',
 'ResponseArea_00-2901',
 'ResponseArea_00-2902',
 'ResponseArea_00-2903',
 'ResponseArea_00-2904',
 'ResponseArea_00-3001',
 'ResponseArea_00-3002',
 'ResponseArea_00-3003',
 'ResponseArea_00-3004',
 'ResponseArea_00-3005',
 'ResponseArea_00-3102',
 'ResponseArea_00-3105',
 'ResponseArea_00-3106',
 'ResponseArea_00-3201',
 'ResponseArea_00-3203',
 'ResponseArea_00-3209',
 'ResponseArea_00-3303',
 'ResponseArea_00-3304',
 'ResponseArea_00-3401',
 'ResponseArea_00-3403',
 'ResponseArea_00-3404',
 'ResponseArea_00-3501',
 'ResponseArea_00-3502',
 'ResponseArea_00-3503',
 'ResponseArea_00-3504',
 'ResponseArea_00-3601',
 'ResponseArea_00-3602',
 'ResponseArea_00-3603',
 'ResponseArea_00-3604',
 'ResponseArea_00-3606',
 'ResponseArea_00-3607',
 'ResponseArea_00-3608',
 'ResponseArea_00-3611',
 'ResponseArea_00-3802',
 'ResponseArea_00-3808',
 'ResponseArea_00-3809',
 'ResponseArea_00-3810',
 'ResponseArea_00-3901',
 'ResponseArea_00-3906',
 'ResponseArea_00-3907',
 'ResponseArea_00-3908',
 'ResponseArea_00-4001',
 'ResponseArea_00-4002',
 'ResponseArea_00-4003',
 'ResponseArea_00-4004',
 'ResponseArea_00-4005',
 'ResponseArea_00-4101',
 'ResponseArea_00-4103',
 'ResponseArea_00-4105',
 'ResponseArea_00-4201',
 'ResponseArea_00-4209',
 'ResponseArea_00-4302',
 'ResponseArea_00-4401',
 'ResponseArea_00-4502',
 'ResponseArea_00-4504',
 'day_of_week_0',
 'day_of_week_1',
 'day_of_week_2',
 'day_of_week_3',
 'day_of_week_4',
 'day_of_week_5',
 'day_of_week_6',
 'hour_0',
 'hour_1',
 'hour_2',
 'hour_3',
 'hour_4',
 'hour_5',
 'hour_6',
 'hour_7',
 'hour_8',
 'hour_9',
 'hour_10',
 'hour_11',
 'hour_12',
 'hour_13',
 'hour_14',
 'hour_15',
 'hour_16',
 'hour_17',
 'hour_18',
 'hour_19',
 'hour_20',
 'hour_21',
 'hour_22',
 'hour_23'
]

# %%
rf = RandomForestClassifier()
rf.fit(df_dummies_2016[features], df_dummies_2016['late_response'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
zipped = zip(features, rf.feature_importances_)
zipped_sorted = sorted(zipped, key=lambda x: x[1], reverse=True)
for feat, importance in zipped_sorted:
    print('feature: {f}, importance: {i}'.format(f=feat, i=importance))
# Out:
# feature: ResponseArea_00-2404, importance: 0.05433250954518354
# feature: ResponseArea_00-3602, importance: 0.031840875751433975
# feature: ResponseArea_00-2001, importance: 0.031504890636066415
# feature: ResponseArea_00-3209, importance: 0.0314533349566982
# feature: ResponseArea_00-3608, importance: 0.028693426552989433
# feature: Problem_DUMP - Dumpster Fire, importance: 0.024955308182608486
# feature: Problem_TRASH - Trash Fire, importance: 0.02390222868824215
# feature: day_of_week_6, importance: 0.023299993103289243
# feature: ResponseArea_00-2704, importance: 0.023014184827794524
# feature: ResponseArea_00-2607, importance: 0.02258141858737828
# feature: ResponseArea_00-3504, importance: 0.02148484318241485
# feature: Problem_AUTO - Auto Fire, importance: 0.02113666617721444
# feature: day_of_week_0, importance: 0.02110220235393532
# feature: ResponseArea_00-1712, importance: 0.020226249923031108
# feature: hour_15, importance: 0.020189277103751433
# feature: ResponseArea_00-4401, importance: 0.01989017029801461
# feature: ResponseArea_00-2401, importance: 0.01952218522265897
# feature: day_of_week_5, importance: 0.018470891583332573
# feature: hour_21, importance: 0.0181212730832931
# feature: day_of_week_3, importance: 0.018070611211666948
# feature: ResponseArea_00-4005, importance: 0.017348463736629856
# feature: ResponseArea_00-2304, importance: 0.017295853237248193
# feature: ResponseArea_00-3401, importance: 0.015844970062091176
# feature: ResponseArea_00-1706, importance: 0.015626995350560096
# feature: day_of_week_2, importance: 0.015375287986158757
# feature: day_of_week_4, importance: 0.015310274812955155
# feature: ResponseArea_00-2402, importance: 0.0150589129923556
# feature: ResponseArea_00-3102, importance: 0.014805881312770292
# feature: ResponseArea_00-0401, importance: 0.014788099894625017
# feature: ResponseArea_00-0701, importance: 0.01427324709874359
# feature: hour_22, importance: 0.014170220179780918
# feature: ResponseArea_00-3604, importance: 0.014138100568448265
# feature: ResponseArea_00-4209, importance: 0.013767525256862718
# feature: ResponseArea_00-3611, importance: 0.013688821587995911
# feature: hour_2, importance: 0.013472513235968315
# feature: ResponseArea_00-3607, importance: 0.01327656057627557
# feature: ResponseArea_00-3808, importance: 0.012466560131948889
# feature: hour_8, importance: 0.012304591854060156
# feature: hour_13, importance: 0.012101650377274585
# feature: ResponseArea_00-3106, importance: 0.011933396973930447
# feature: ResponseArea_00-1804, importance: 0.011808770392001644
# feature: ResponseArea_00-3501, importance: 0.011537505380831195
# feature: Problem_ELEC - Electrical Fire, importance: 0.011066753069451898
# feature: ResponseArea_00-2601, importance: 0.01046012305453274
# feature: hour_12, importance: 0.01012142453538834
# feature: hour_7, importance: 0.00994475703153587
# feature: hour_23, importance: 0.009568150892972607
# feature: day_of_week_1, importance: 0.00932581203614021
# feature: hour_20, importance: 0.008584946359270438
# feature: Problem_GRASS - Small Grass Fire, importance: 0.008082513276268506
# feature: hour_9, importance: 0.0074515160002243145
# feature: ResponseArea_00-1505, importance: 0.006960008949879965
# feature: ResponseArea_00-0202, importance: 0.006915432844157532
# feature: ResponseArea_00-1601, importance: 0.006604161178629045
# feature: ResponseArea_00-0804, importance: 0.006209609129149595
# feature: ResponseArea_00-2803, importance: 0.006052452236830729
# feature: hour_17, importance: 0.005539410545952887
# feature: ResponseArea_00-0504, importance: 0.0049132828254235955
# feature: hour_11, importance: 0.004394003608257605
# feature: hour_19, importance: 0.004209956680587256
# feature: ResponseArea_00-3810, importance: 0.004166360193710749
# feature: hour_16, importance: 0.0036277752049678714
# feature: hour_18, importance: 0.0032520549911298885
# feature: hour_10, importance: 0.0029892784867363575
# feature: ResponseArea_00-4001, importance: 0.0029666905351928416
# feature: hour_1, importance: 0.0029406360004986592
# feature: ResponseArea_00-3005, importance: 0.002798346839690812
# feature: ResponseArea_00-2205, importance: 0.002708442358554376
# feature: hour_4, importance: 0.0024147361500983467
# feature: ResponseArea_00-3502, importance: 0.0023903945503289084
# feature: ResponseArea_00-0101, importance: 0.0022934019825860625
# feature: hour_14, importance: 0.002204994431021844
# feature: ResponseArea_00-3203, importance: 0.0020271374856956023
# feature: ResponseArea_00-1801, importance: 0.0016913862543335508
# feature: ResponseArea_00-2806, importance: 0.0016854920311121704
# feature: hour_5, importance: 0.0014502923976608185
# feature: ResponseArea_00-3201, importance: 0.001339972538615736
# feature: ResponseArea_00-3001, importance: 0.0013196158420646666
# feature: ResponseArea_00-1605, importance: 0.0013150662447591994
# feature: ResponseArea_00-0803, importance: 0.0011293984032855076
# feature: ResponseArea_00-0301, importance: 0.0010815122710486128
# feature: ResponseArea_00-1606, importance: 0.000997586484312148
# feature: ResponseArea_00-2006, importance: 0.0009968429295767853
# feature: ResponseArea_00-1803, importance: 0.0008116389111096975
# feature: ResponseArea_00-1205, importance: 0.0007601765571358508
# feature: hour_0, importance: 0.000627517014385584
# feature: ResponseArea_00-1604, importance: 0.0005410476252808868
# feature: ResponseArea_00-1001, importance: 0.00047305674773485864
# feature: ResponseArea_00-3004, importance: 0.0004560281269181143
# feature: ResponseArea_00-0102, importance: 0.0003939875849218291
# feature: ResponseArea_00-2801, importance: 0.0003907097068081559
# feature: ResponseArea_00-1805, importance: 0.0003564395516327717
# feature: ResponseArea_00-0303, importance: 0.0003205751942184336
# feature: Problem_BBQ - Unsafe Cooking, importance: 0.0002994828772981937
# feature: ResponseArea_00-2606, importance: 0.00029566046733428704
# feature: ResponseArea_00-2202, importance: 0.0002408170649646844
# feature: ResponseArea_00-4003, importance: 0.0002313257977033167
# feature: ResponseArea_00-0805, importance: 0.00019636313747348669
# feature: ResponseArea_00-0201, importance: 0.00018583627823887127
# feature: ResponseArea_00-3303, importance: 0.00018161039170267493
# feature: ResponseArea_00-1603, importance: 0.00015790032061587165
# feature: ResponseArea_00-2201, importance: 0.00015720296281632737
# feature: ResponseArea_00-1709, importance: 0.00015655179246366687
# feature: ResponseArea_00-4101, importance: 0.00015615539631671317
# feature: ResponseArea_00-2204, importance: 0.00013911835816818397
# feature: ResponseArea_00-1405, importance: 0.00013515907078139256
# feature: ResponseArea_00-1901, importance: 0.0001235935203660521
# feature: ResponseArea_00-4002, importance: 0.00010887465566791422
# feature: ResponseArea_00-2305, importance: 0.00010849577966211068
# feature: ResponseArea_00-1708, importance: 9.072887972326086e-05
# feature: ResponseArea_00-0505, importance: 8.8109519554273e-05
# feature: ResponseArea_00-3906, importance: 8.7958510773667e-05
# feature: ResponseArea_00-2901, importance: 8.752111636794861e-05
# feature: ResponseArea_00-0903, importance: 8.685539717350206e-05
# feature: ResponseArea_00-2501, importance: 8.027899307855386e-05
# feature: ResponseArea_00-1504, importance: 7.884279128914527e-05
# feature: ResponseArea_00-2608, importance: 7.228887567479478e-05
# feature: ResponseArea_00-1204, importance: 7.11639285197358e-05
# feature: ResponseArea_00-3002, importance: 6.927683918834339e-05
# feature: ResponseArea_00-2903, importance: 6.183401431781542e-05
# feature: ResponseArea_00-2403, importance: 5.938014787572345e-05
# feature: ResponseArea_00-2301, importance: 5.769508464890115e-05
# feature: ResponseArea_00-0603, importance: 5.331573877970736e-05
# feature: ResponseArea_00-0802, importance: 5.163079234171487e-05
# feature: ResponseArea_00-4105, importance: 4.874323208575745e-05
# feature: ResponseArea_00-0601, importance: 4.462966701491905e-05
# feature: ResponseArea_00-2804, importance: 4.293414756010882e-05
# feature: ResponseArea_00-0902, importance: 4.2435107865168176e-05
# feature: hour_3, importance: 4.2092112495812005e-05
# feature: ResponseArea_00-1003, importance: 4.156610351300547e-05
# feature: ResponseArea_00-1101, importance: 3.417142896511092e-05
# feature: ResponseArea_00-1802, importance: 3.3769320674687726e-05
# feature: ResponseArea_00-2102, importance: 3.116078967472316e-05
# feature: ResponseArea_00-1707, importance: 2.6681946983922598e-05
# feature: ResponseArea_00-1401, importance: 2.581879041326417e-05
# feature: ResponseArea_00-0501, importance: 1.9494096747317917e-05
# feature: ResponseArea_00-1202, importance: 1.8583627823888134e-05
# feature: ResponseArea_00-1206, importance: 1.4479553469254251e-05
# feature: ResponseArea_00-2504, importance: 1.4320437497069852e-05
# feature: ResponseArea_00-0702, importance: 1.0006568828246897e-05
# feature: ResponseArea_00-0807, importance: 7.381328037822314e-06
# feature: hour_6, importance: 7.273526357007569e-06
# feature: ResponseArea_00-1703, importance: 6.8346897987851746e-06
# feature: ResponseArea_00-1404, importance: 2.7825752891394664e-06
# feature: ResponseArea_00-3601, importance: 1.7074405301277334e-06
# feature: ResponseArea_00-4502, importance: 1.5682539863161564e-06
# feature: ResponseArea_00-1102, importance: 8.869012129415268e-07
# feature: Problem_BOXL- Structure Fire, importance: 0.0
# feature: Problem_BRSHL - Brush Alarm / Light, importance: 0.0
# feature: ResponseArea_00-0203, importance: 0.0
# feature: ResponseArea_00-0502, importance: 0.0
# feature: ResponseArea_00-0503, importance: 0.0
# feature: ResponseArea_00-0602, importance: 0.0
# feature: ResponseArea_00-0604, importance: 0.0
# feature: ResponseArea_00-0801, importance: 0.0
# feature: ResponseArea_00-0806, importance: 0.0
# feature: ResponseArea_00-1002, importance: 0.0
# feature: ResponseArea_00-1103, importance: 0.0
# feature: ResponseArea_00-1104, importance: 0.0
# feature: ResponseArea_00-1201, importance: 0.0
# feature: ResponseArea_00-1403, importance: 0.0
# feature: ResponseArea_00-1501, importance: 0.0
# feature: ResponseArea_00-1602, importance: 0.0
# feature: ResponseArea_00-1701, importance: 0.0
# feature: ResponseArea_00-1705, importance: 0.0
# feature: ResponseArea_00-1710, importance: 0.0
# feature: ResponseArea_00-1903, importance: 0.0
# feature: ResponseArea_00-2002, importance: 0.0
# feature: ResponseArea_00-2004, importance: 0.0
# feature: ResponseArea_00-2005, importance: 0.0
# feature: ResponseArea_00-2101, importance: 0.0
# feature: ResponseArea_00-2103, importance: 0.0
# feature: ResponseArea_00-2104, importance: 0.0
# feature: ResponseArea_00-2203, importance: 0.0
# feature: ResponseArea_00-2206, importance: 0.0
# feature: ResponseArea_00-2303, importance: 0.0
# feature: ResponseArea_00-2306, importance: 0.0
# feature: ResponseArea_00-2502, importance: 0.0
# feature: ResponseArea_00-2701, importance: 0.0
# feature: ResponseArea_00-2705, importance: 0.0
# feature: ResponseArea_00-2706, importance: 0.0
# feature: ResponseArea_00-27SV, importance: 0.0
# feature: ResponseArea_00-2805, importance: 0.0
# feature: ResponseArea_00-2808, importance: 0.0
# feature: ResponseArea_00-2902, importance: 0.0
# feature: ResponseArea_00-2904, importance: 0.0
# feature: ResponseArea_00-3003, importance: 0.0
# feature: ResponseArea_00-3105, importance: 0.0
# feature: ResponseArea_00-3304, importance: 0.0
# feature: ResponseArea_00-3403, importance: 0.0
# feature: ResponseArea_00-3404, importance: 0.0
# feature: ResponseArea_00-3503, importance: 0.0
# feature: ResponseArea_00-3603, importance: 0.0
# feature: ResponseArea_00-3606, importance: 0.0
# feature: ResponseArea_00-3802, importance: 0.0
# feature: ResponseArea_00-3809, importance: 0.0
# feature: ResponseArea_00-3901, importance: 0.0
# feature: ResponseArea_00-3907, importance: 0.0
# feature: ResponseArea_00-3908, importance: 0.0
# feature: ResponseArea_00-4004, importance: 0.0
# feature: ResponseArea_00-4103, importance: 0.0
# feature: ResponseArea_00-4201, importance: 0.0
# feature: ResponseArea_00-4302, importance: 0.0
# feature: ResponseArea_00-4504, importance: 0.0
