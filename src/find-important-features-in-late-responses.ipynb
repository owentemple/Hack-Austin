# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import settings
import pandas as pd
import numpy as np
import operator
import matplotlib
import matplotlib.pyplot as plt

import graphviz
from sklearn.tree import export_graphviz
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
# Out:
# /Users/owentemple/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Assemble the master dataset from smaller datasets

# %%
def concatenate():
    # Create Super Dataset
    # From files downloaded from https://github.com/cityofaustin/hack-austin/tree/master/Austin%20Fire%20Department%20Data

    # 2012
    fire_2012 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_CY12 - SOC Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2012.dropna(inplace=True)
    fire_2012.index = pd.to_datetime(fire_2012.index)

    # 2013
    fire_2013 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_CY13 - SOC Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2013.dropna(inplace=True)
    fire_2013.index = pd.to_datetime(fire_2013.index)

    # 2014
    fire_2014 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_CY14 - SOC Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2014.dropna(inplace=True)
    fire_2014.index = pd.to_datetime(fire_2014.index)

    # 2015
    fire_2015 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_CY15 - SOC Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2015.dropna(inplace=True)
    fire_2015.index = pd.to_datetime(fire_2015.index)

    # 2016
    fire_2016 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_CY16 - SOC Fire Data Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2016.dropna(inplace=True)
    fire_2016.index = pd.to_datetime(fire_2016.index)

    # 2017
    fire_2017 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_CY17 - SOC Filtered Data_Generalized.csv'), index_col='AFD Time Phone Pickup')
    fire_2017.dropna(inplace=True)
    fire_2017.index = pd.to_datetime(fire_2017.index)

    # Combine all years into single dataframe
    final_df = pd.concat([fire_2012, fire_2013, fire_2014, fire_2015, fire_2016, fire_2017])

    # Calculate time between AFD phone pickup and first unit arrival in seconds and in minutes
    final_df['First Unit Arrived'] = pd.to_datetime(final_df['First Unit Arrived'])
    final_df['Response Time (s)'] = (final_df['First Unit Arrived'] - final_df.index).astype('timedelta64[s]')
    final_df['Response Time (m)'] = ((final_df['First Unit Arrived'] - final_df.index).astype('timedelta64[s]')) / 60
    final_df.reset_index(inplace=True)

    # Read in incident detail reports for all years available
    # Downloaded from https://data.austintexas.gov/browse?q=AFD&sortBy=relevance&anonymous=true
    AFD_13 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_Fire_Incidents_2013_January_Thru_December.csv'))
    AFD_14 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_Fire_Incidents_2014_January_Thru_December.csv'))
    AFD_15 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_Fire_Incidents_2015_January_Thru_December.csv'))
    AFD_16 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_Fire_Incidents_2016_January_Thru_December.csv'))
    AFD_17 = pd.read_csv(os.path.join('..', settings.DATA_DIR, 'AFD_Fire_Incidents_2017_January_Thru_December.csv'))

    # Concatenate all years incident detail reports into one dataframe
    frames = [AFD_13, AFD_14, AFD_15, AFD_16, AFD_17]
    result = pd.concat(frames)
    result = result.rename(index=str, columns={"MasterIncidentNumber": "Master Incident Number"})

    # Join dataframe with response time information with problem detail dataframe
    detail_final_df = pd.merge(final_df, result, how='inner', on='Master Incident Number')
    detail_final_df['day_of_week'] = detail_final_df['First Unit Arrived'].dt.dayofweek
    detail_final_df['hour'] = detail_final_df['First Unit Arrived'].dt.hour
    detail_final_df['late_response'] = np.where(detail_final_df['Response Time (s)'] > (60 * 8), 1, 0)

    del detail_final_df['CalendarYear_y']
    del detail_final_df['PriorityDescription_y']
    del detail_final_df['Response Status_y']
    detail_final_df.rename(columns={'CalendarYear_x': 'CalendarYear', 'Response Status_x': 'Response Status',
                                    'PriorityDescription_x': 'PriorityDescription'}, inplace=True)

    detail_final_df.to_csv(os.path.join('..', settings.PROCESSED_DIR, 'All Years with Response Times and Problem Types.csv'))
    df = detail_final_df
    return df

def create_dummies(df):
    df = pd.get_dummies(df, columns=['Problem', 'ResponseArea', 'day_of_week', 'hour'])
    return df

def write_data():
    df.to_csv(os.path.join('..', settings.PROCESSED_DIR, "all_years_with_RT-and-PT-dummies.csv"), index_label='index')
    pass

# %%
df = concatenate()
df = create_dummies(df)
write_data()

# %% [markdown]
# ## Fit decision tree classifier to see features with highest splits in classifying a late response

# %%
def read_data():
    df = pd.read_csv(os.path.join('..', settings.PROCESSED_DIR, "all_years_with_RT-and-PT.csv"))
    return df

def limit_time_period(df):
    df = df[df['CalendarYear'] >= settings.YEARS_OF_ANALYSES]
    return df

# Fit decision tree regressor using features and response variable set in settings.py
# Prints feature importances sorted by descending by magnitude
def sort_important_features(df):
    dt = DecisionTreeClassifier()
    predictors = df.columns.tolist()
    predictors = [p for p in predictors if p not in settings.NON_PREDICTORS]
    model = dt.fit(df[predictors], df[settings.TARGET])
    results = {name: score for name, score in zip(predictors, dt.feature_importances_)}
    sorted_results = sorted(results.items(), key=operator.itemgetter(1), reverse=True)
    print("Feature Importances for the Response Variable: {}".format(settings.TARGET))
    for feat, importance in sorted_results:
        print("feature: {f}, importance: {i}".format(f=feat, i=importance))
    accuracy = dt.score(df[predictors], df[settings.TARGET])
    print("Accuracy: {}".format(accuracy))
    return model

def print_tree(model):
    # Saves the figure of the decision tree in the 'images' folder
    PROJECT_ROOT_DIR = ".."
    IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images")
    path = os.path.join(IMAGES_PATH, "Decision Tree Predicting {}".format(settings.TARGET))
    predictors = df.columns.tolist()
    features = [p for p in predictors if p not in settings.NON_PREDICTORS]
    data = export_graphviz(model, out_file=None, feature_names=features)
    graph = graphviz.Source(data)
    graph.render(path, view=True)
    pass

# %%
df = read_data()
df = limit_time_period(df)
model = sort_important_features(df)
print_tree(model)
# Out:
# Feature Importances for the Response Variable: late_response
# feature: ResponseArea_00-2404, importance: 0.052518401296182474
# feature: hour_15, importance: 0.050388846073004964
# feature: Problem_DUMP - Dumpster Fire, importance: 0.04561059342815105
# feature: hour_23, importance: 0.04256988719960766
# feature: day_of_week_2, importance: 0.040542749713912044
# feature: day_of_week_4, importance: 0.030407062285434033
# feature: ResponseArea_00-1505, importance: 0.02752311816469794
# feature: ResponseArea_00-4005, importance: 0.027409620770204788
# feature: ResponseArea_00-4209, importance: 0.027296823976911723
# feature: ResponseArea_00-2001, importance: 0.027184722030394706
# feature: ResponseArea_00-3808, importance: 0.027073309235187797
# feature: ResponseArea_00-3209, importance: 0.026962579954062198
# feature: ResponseArea_00-3102, importance: 0.026852528607311407
# feature: ResponseArea_00-3106, importance: 0.026743149672046912
# feature: ResponseArea_00-3608, importance: 0.026634437681511112
# feature: ResponseArea_00-3602, importance: 0.026526387224384433
# feature: ResponseArea_00-2607, importance: 0.02641899294412345
# feature: hour_12, importance: 0.02606319624465775
# feature: hour_22, importance: 0.02533921857119503
# feature: Problem_GRASS - Small Grass Fire, importance: 0.024325649828347222
# feature: day_of_week_0, importance: 0.024325649828347222
# feature: hour_21, importance: 0.024325649828347222
# feature: hour_9, importance: 0.022805296714075524
# feature: Problem_AUTO - Auto Fire, importance: 0.020271374856956022
# feature: Problem_TRASH - Trash Fire, importance: 0.020271374856956022
# feature: day_of_week_1, importance: 0.020271374856956022
# feature: day_of_week_5, importance: 0.020271374856956022
# feature: hour_1, importance: 0.020271374856956022
# feature: hour_13, importance: 0.015203531142717016
# feature: ResponseArea_00-0401, importance: 0.015080591537789373
# feature: ResponseArea_00-1712, importance: 0.01313509622496538
# feature: ResponseArea_00-2704, importance: 0.013023545513925271
# feature: ResponseArea_00-3504, importance: 0.012913409822475531
# feature: ResponseArea_00-3810, importance: 0.012804665318707538
# feature: ResponseArea_00-3501, importance: 0.01269728867033333
# feature: ResponseArea_00-3604, importance: 0.011519270965918453
# feature: ResponseArea_00-3607, importance: 0.0088804469801205
# feature: ResponseArea_00-2401, importance: 0.008762041020386186
# feature: ResponseArea_00-3401, importance: 0.00864598749693653
# feature: ResponseArea_00-4401, importance: 0.008532224503556224
# feature: ResponseArea_00-3611, importance: 0.008420692157105234
# feature: ResponseArea_00-1601, importance: 0.00647737665883843
# feature: ResponseArea_00-1804, importance: 0.005451126011954096
# feature: ResponseArea_00-2304, importance: 0.005324355639583416
# feature: ResponseArea_00-2601, importance: 0.0052019566593637
# feature: ResponseArea_00-0202, importance: 0.005083730371650098
# feature: ResponseArea_00-1706, importance: 0.004570502529860763
# feature: ResponseArea_00-2402, importance: 0.004121042789507471
# feature: ResponseArea_00-0804, importance: 0.0039816838545967195
# feature: ResponseArea_00-0701, importance: 0.0029646885728300152
# feature: Problem_BBQ - Unsafe Cooking, importance: 0.0
# feature: Problem_BOX -Structure Fire, importance: 0.0
# feature: Problem_BOXL- Structure Fire, importance: 0.0
# feature: Problem_BRSHL - Brush Alarm / Light, importance: 0.0
# feature: Problem_ELEC - Electrical Fire, importance: 0.0
# feature: ResponseArea_00-0040, importance: 0.0
# feature: ResponseArea_00-0060, importance: 0.0
# feature: ResponseArea_00-0070, importance: 0.0
# feature: ResponseArea_00-0101, importance: 0.0
# feature: ResponseArea_00-0102, importance: 0.0
# feature: ResponseArea_00-0201, importance: 0.0
# feature: ResponseArea_00-0203, importance: 0.0
# feature: ResponseArea_00-0301, importance: 0.0
# feature: ResponseArea_00-0302, importance: 0.0
# feature: ResponseArea_00-0303, importance: 0.0
# feature: ResponseArea_00-0402, importance: 0.0
# feature: ResponseArea_00-0501, importance: 0.0
# feature: ResponseArea_00-0502, importance: 0.0
# feature: ResponseArea_00-0503, importance: 0.0
# feature: ResponseArea_00-0504, importance: 0.0
# feature: ResponseArea_00-0505, importance: 0.0
# feature: ResponseArea_00-0601, importance: 0.0
# feature: ResponseArea_00-0602, importance: 0.0
# feature: ResponseArea_00-0603, importance: 0.0
# feature: ResponseArea_00-0604, importance: 0.0
# feature: ResponseArea_00-0702, importance: 0.0
# feature: ResponseArea_00-0801, importance: 0.0
# feature: ResponseArea_00-0802, importance: 0.0
# feature: ResponseArea_00-0803, importance: 0.0
# feature: ResponseArea_00-0805, importance: 0.0
# feature: ResponseArea_00-0806, importance: 0.0
# feature: ResponseArea_00-0807, importance: 0.0
# feature: ResponseArea_00-0901, importance: 0.0
# feature: ResponseArea_00-0902, importance: 0.0
# feature: ResponseArea_00-0903, importance: 0.0
# feature: ResponseArea_00-1001, importance: 0.0
# feature: ResponseArea_00-1002, importance: 0.0
# feature: ResponseArea_00-1003, importance: 0.0
# feature: ResponseArea_00-1101, importance: 0.0
# feature: ResponseArea_00-1102, importance: 0.0
# feature: ResponseArea_00-1103, importance: 0.0
# feature: ResponseArea_00-1104, importance: 0.0
# feature: ResponseArea_00-1201, importance: 0.0
# feature: ResponseArea_00-1202, importance: 0.0
# feature: ResponseArea_00-1203, importance: 0.0
# feature: ResponseArea_00-1204, importance: 0.0
# feature: ResponseArea_00-1205, importance: 0.0
# feature: ResponseArea_00-1206, importance: 0.0
# feature: ResponseArea_00-1401, importance: 0.0
# feature: ResponseArea_00-1402, importance: 0.0
# feature: ResponseArea_00-1403, importance: 0.0
# feature: ResponseArea_00-1404, importance: 0.0
# feature: ResponseArea_00-1405, importance: 0.0
# feature: ResponseArea_00-1406, importance: 0.0
# feature: ResponseArea_00-1407, importance: 0.0
# feature: ResponseArea_00-1501, importance: 0.0
# feature: ResponseArea_00-1502, importance: 0.0
# feature: ResponseArea_00-1503, importance: 0.0
# feature: ResponseArea_00-1504, importance: 0.0
# feature: ResponseArea_00-1602, importance: 0.0
# feature: ResponseArea_00-1603, importance: 0.0
# feature: ResponseArea_00-1604, importance: 0.0
# feature: ResponseArea_00-1605, importance: 0.0
# feature: ResponseArea_00-1606, importance: 0.0
# feature: ResponseArea_00-1701, importance: 0.0
# feature: ResponseArea_00-1702, importance: 0.0
# feature: ResponseArea_00-1703, importance: 0.0
# feature: ResponseArea_00-1704, importance: 0.0
# feature: ResponseArea_00-1705, importance: 0.0
# feature: ResponseArea_00-1707, importance: 0.0
# feature: ResponseArea_00-1708, importance: 0.0
# feature: ResponseArea_00-1709, importance: 0.0
# feature: ResponseArea_00-1710, importance: 0.0
# feature: ResponseArea_00-17SV, importance: 0.0
# feature: ResponseArea_00-1801, importance: 0.0
# feature: ResponseArea_00-1802, importance: 0.0
# feature: ResponseArea_00-1803, importance: 0.0
# feature: ResponseArea_00-1805, importance: 0.0
# feature: ResponseArea_00-1901, importance: 0.0
# feature: ResponseArea_00-1902, importance: 0.0
# feature: ResponseArea_00-1903, importance: 0.0
# feature: ResponseArea_00-1904, importance: 0.0
# feature: ResponseArea_00-1905, importance: 0.0
# feature: ResponseArea_00-2002, importance: 0.0
# feature: ResponseArea_00-2003, importance: 0.0
# feature: ResponseArea_00-2004, importance: 0.0
# feature: ResponseArea_00-2005, importance: 0.0
# feature: ResponseArea_00-2006, importance: 0.0
# feature: ResponseArea_00-2101, importance: 0.0
# feature: ResponseArea_00-2102, importance: 0.0
# feature: ResponseArea_00-2103, importance: 0.0
# feature: ResponseArea_00-2104, importance: 0.0
# feature: ResponseArea_00-2201, importance: 0.0
# feature: ResponseArea_00-2202, importance: 0.0
# feature: ResponseArea_00-2203, importance: 0.0
# feature: ResponseArea_00-2204, importance: 0.0
# feature: ResponseArea_00-2205, importance: 0.0
# feature: ResponseArea_00-2206, importance: 0.0
# feature: ResponseArea_00-2301, importance: 0.0
# feature: ResponseArea_00-2302, importance: 0.0
# feature: ResponseArea_00-2303, importance: 0.0
# feature: ResponseArea_00-2305, importance: 0.0
# feature: ResponseArea_00-2306, importance: 0.0
# feature: ResponseArea_00-2403, importance: 0.0
# feature: ResponseArea_00-2501, importance: 0.0
# feature: ResponseArea_00-2502, importance: 0.0
# feature: ResponseArea_00-2503, importance: 0.0
# feature: ResponseArea_00-2504, importance: 0.0
# feature: ResponseArea_00-2604, importance: 0.0
# feature: ResponseArea_00-2605, importance: 0.0
# feature: ResponseArea_00-2606, importance: 0.0
# feature: ResponseArea_00-2608, importance: 0.0
# feature: ResponseArea_00-2610, importance: 0.0
# feature: ResponseArea_00-2611, importance: 0.0
# feature: ResponseArea_00-2701, importance: 0.0
# feature: ResponseArea_00-2702, importance: 0.0
# feature: ResponseArea_00-2703, importance: 0.0
# feature: ResponseArea_00-2705, importance: 0.0
# feature: ResponseArea_00-2706, importance: 0.0
# feature: ResponseArea_00-27SV, importance: 0.0
# feature: ResponseArea_00-2801, importance: 0.0
# feature: ResponseArea_00-2803, importance: 0.0
# feature: ResponseArea_00-2804, importance: 0.0
# feature: ResponseArea_00-2805, importance: 0.0
# feature: ResponseArea_00-2806, importance: 0.0
# feature: ResponseArea_00-2807, importance: 0.0
# feature: ResponseArea_00-2808, importance: 0.0
# feature: ResponseArea_00-2901, importance: 0.0
# feature: ResponseArea_00-2902, importance: 0.0
# feature: ResponseArea_00-2903, importance: 0.0
# feature: ResponseArea_00-2904, importance: 0.0
# feature: ResponseArea_00-2905, importance: 0.0
# feature: ResponseArea_00-2906, importance: 0.0
# feature: ResponseArea_00-2907, importance: 0.0
# feature: ResponseArea_00-2910, importance: 0.0
# feature: ResponseArea_00-3001, importance: 0.0
# feature: ResponseArea_00-3002, importance: 0.0
# feature: ResponseArea_00-3003, importance: 0.0
# feature: ResponseArea_00-3004, importance: 0.0
# feature: ResponseArea_00-3005, importance: 0.0
# feature: ResponseArea_00-3101, importance: 0.0
# feature: ResponseArea_00-3103, importance: 0.0
# feature: ResponseArea_00-3104, importance: 0.0
# feature: ResponseArea_00-3105, importance: 0.0
# feature: ResponseArea_00-3107, importance: 0.0
# feature: ResponseArea_00-3201, importance: 0.0
# feature: ResponseArea_00-3202, importance: 0.0
# feature: ResponseArea_00-3203, importance: 0.0
# feature: ResponseArea_00-3204, importance: 0.0
# feature: ResponseArea_00-3205, importance: 0.0
# feature: ResponseArea_00-3207, importance: 0.0
# feature: ResponseArea_00-3301, importance: 0.0
# feature: ResponseArea_00-3303, importance: 0.0
# feature: ResponseArea_00-3304, importance: 0.0
# feature: ResponseArea_00-3400, importance: 0.0
# feature: ResponseArea_00-3402, importance: 0.0
# feature: ResponseArea_00-3403, importance: 0.0
# feature: ResponseArea_00-3404, importance: 0.0
# feature: ResponseArea_00-3502, importance: 0.0
# feature: ResponseArea_00-3503, importance: 0.0
# feature: ResponseArea_00-3505, importance: 0.0
# feature: ResponseArea_00-3507, importance: 0.0
# feature: ResponseArea_00-3508, importance: 0.0
# feature: ResponseArea_00-3601, importance: 0.0
# feature: ResponseArea_00-3603, importance: 0.0
# feature: ResponseArea_00-3605, importance: 0.0
# feature: ResponseArea_00-3606, importance: 0.0
# feature: ResponseArea_00-3610, importance: 0.0
# feature: ResponseArea_00-3701, importance: 0.0
# feature: ResponseArea_00-3702, importance: 0.0
# feature: ResponseArea_00-3703, importance: 0.0
# feature: ResponseArea_00-3801, importance: 0.0
# feature: ResponseArea_00-3802, importance: 0.0
# feature: ResponseArea_00-3804, importance: 0.0
# feature: ResponseArea_00-3809, importance: 0.0
# feature: ResponseArea_00-3901, importance: 0.0
# feature: ResponseArea_00-3902, importance: 0.0
# feature: ResponseArea_00-3904, importance: 0.0
# feature: ResponseArea_00-3906, importance: 0.0
# feature: ResponseArea_00-3907, importance: 0.0
# feature: ResponseArea_00-3908, importance: 0.0
# feature: ResponseArea_00-4001, importance: 0.0
# feature: ResponseArea_00-4002, importance: 0.0
# feature: ResponseArea_00-4003, importance: 0.0
# feature: ResponseArea_00-4004, importance: 0.0
# feature: ResponseArea_00-4006, importance: 0.0
# feature: ResponseArea_00-4101, importance: 0.0
# feature: ResponseArea_00-4102, importance: 0.0
# feature: ResponseArea_00-4103, importance: 0.0
# feature: ResponseArea_00-4104, importance: 0.0
# feature: ResponseArea_00-4105, importance: 0.0
# feature: ResponseArea_00-4107, importance: 0.0
# feature: ResponseArea_00-4108, importance: 0.0
# feature: ResponseArea_00-4201, importance: 0.0
# feature: ResponseArea_00-4202, importance: 0.0
# feature: ResponseArea_00-4203, importance: 0.0
# feature: ResponseArea_00-4204, importance: 0.0
# feature: ResponseArea_00-4205, importance: 0.0
# feature: ResponseArea_00-4210, importance: 0.0
# feature: ResponseArea_00-4301, importance: 0.0
# feature: ResponseArea_00-4302, importance: 0.0
# feature: ResponseArea_00-4303, importance: 0.0
# feature: ResponseArea_00-4305, importance: 0.0
# feature: ResponseArea_00-4402, importance: 0.0
# feature: ResponseArea_00-4403, importance: 0.0
# feature: ResponseArea_00-4404, importance: 0.0
# feature: ResponseArea_00-4405, importance: 0.0
# feature: ResponseArea_00-4501, importance: 0.0
# feature: ResponseArea_00-4502, importance: 0.0
# feature: ResponseArea_00-4503, importance: 0.0
# feature: ResponseArea_00-4504, importance: 0.0
# feature: ResponseArea_00-4505, importance: 0.0
# feature: ResponseArea_00-4506, importance: 0.0
# feature: day_of_week_3, importance: 0.0
# feature: day_of_week_6, importance: 0.0
# feature: hour_0, importance: 0.0
# feature: hour_2, importance: 0.0
# feature: hour_3, importance: 0.0
# feature: hour_4, importance: 0.0
# feature: hour_5, importance: 0.0
# feature: hour_6, importance: 0.0
# feature: hour_7, importance: 0.0
# feature: hour_8, importance: 0.0
# feature: hour_10, importance: 0.0
# feature: hour_11, importance: 0.0
# feature: hour_14, importance: 0.0
# feature: hour_16, importance: 0.0
# feature: hour_17, importance: 0.0
# feature: hour_18, importance: 0.0
# feature: hour_19, importance: 0.0
# feature: hour_20, importance: 0.0
# Accuracy: 0.9979838709677419
# /Users/owentemple/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %% [markdown]
# ## Run random forest classifier to find important features in late responses

# %%
# Read in the data
def read_data():
    df = pd.read_csv(os.path.join('..', settings.PROCESSED_DIR, "all_years_with_RT-and-PT.csv"))
    return df

def limit_time_period(df):
    df = df[df['CalendarYear'] >= settings.YEARS_OF_ANALYSES]
    return df

# Fit random forest regressor and store feature importances and column names in a dictionary
# Print sorted feature importances descending by magnitude
def sort_important_features(df):
    rf = RandomForestClassifier()
    predictors = df.columns.tolist()
    predictors = [p for p in predictors if p not in settings.NON_PREDICTORS]
    model = rf.fit(df[predictors], df[settings.TARGET])
    importances = rf.feature_importances_

    results = {name: score for name, score in zip(predictors, importances)}
    print("Feature Importances for the Response Variable: {}".format(settings.TARGET))
    sorted_results = sorted(results.items(), key=operator.itemgetter(1), reverse=True)
    for feat, importance in sorted_results:
        print('feature: {f}, importance: {i}'.format(f=feat, i=importance))
    accuracy = rf.score(df[predictors], df[settings.TARGET])
    print("Accuracy: {}".format(accuracy))
    names = [k[0] for k in sorted_results]
    return model, importances, names

# Create horizontal bar chart showing feature importances descending by magnitude
def plot_feature_importances(df, importances, names):
    reversed_names = names[::-1]
    predictors = df.columns.tolist()
    predictors = [p for p in predictors if p not in settings.NON_PREDICTORS]
    features = predictors
    indices = np.argsort(importances)

    plt.figure(figsize=(30, 90))
    matplotlib.rcParams.update({'font.size': 22})
    plt.title('Feature Importances Predicting {}'.format(settings.TARGET))
    plt.barh(range(len(indices)), importances[indices], color='b', align='center')
    plt.yticks(range(len(indices)), reversed_names)
    plt.xlabel('Relative Importance')
    save_fig('Feature Importances Predicting {}'.format(settings.TARGET))
    pass

# Save the figure of feature importances in the 'images' folder
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    # Where to save the figures
    PROJECT_ROOT_DIR = ".."
    IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images")
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
    pass

# %%
df = read_data()
rf, importances, names = sort_important_features(df)
plot_feature_importances(df, importances, names)
# Out:
# /Users/owentemple/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# Feature Importances for the Response Variable: late_response
# feature: day_of_week_0, importance: 0.027817449764420698
# feature: day_of_week_4, importance: 0.027101820889883006
# feature: day_of_week_6, importance: 0.025825292403702748
# feature: day_of_week_1, importance: 0.024154610195773238
# feature: day_of_week_2, importance: 0.023954975673587446
# feature: day_of_week_3, importance: 0.023615438610396437
# feature: day_of_week_5, importance: 0.022949185255625733
# feature: Problem_ELEC - Electrical Fire, importance: 0.020945482005449562
# feature: ResponseArea_00-3603, importance: 0.019710320610650277
# feature: hour_17, importance: 0.018634038039287704
# feature: hour_18, importance: 0.017998259500823288
# feature: Problem_GRASS - Small Grass Fire, importance: 0.01771994346660672
# feature: hour_15, importance: 0.01729695658208947
# feature: Problem_TRASH - Trash Fire, importance: 0.014450292406309795
# feature: hour_21, importance: 0.014256084678473373
# feature: hour_14, importance: 0.014007801607837055
# feature: Problem_AUTO - Auto Fire, importance: 0.013968550153744885
# feature: hour_16, importance: 0.013225394965494366
# feature: hour_13, importance: 0.012178674105179437
# feature: hour_19, importance: 0.011758170547133306
# feature: hour_20, importance: 0.011502245480531987
# feature: ResponseArea_00-3602, importance: 0.011149555136018372
# feature: hour_12, importance: 0.010359481964387341
# feature: hour_0, importance: 0.009831973411715933
# feature: ResponseArea_00-2703, importance: 0.009349493384872998
# feature: hour_23, importance: 0.009067634246369716
# feature: hour_7, importance: 0.009045007312740428
# feature: hour_22, importance: 0.008955286613670206
# feature: ResponseArea_00-4108, importance: 0.00878121851963316
# feature: ResponseArea_00-2904, importance: 0.008282359296590543
# feature: hour_8, importance: 0.008151843356237014
# feature: ResponseArea_00-2403, importance: 0.007996715467556852
# feature: ResponseArea_00-4209, importance: 0.007900300218265665
# feature: hour_2, importance: 0.007421978814115317
# feature: hour_11, importance: 0.007254614504140021
# feature: ResponseArea_00-2402, importance: 0.006863485845713743
# feature: ResponseArea_00-3611, importance: 0.006794506227525978
# feature: ResponseArea_00-3607, importance: 0.006703327159722443
# feature: ResponseArea_00-2304, importance: 0.00664116064124899
# feature: hour_9, importance: 0.006548045385843355
# feature: ResponseArea_00-3504, importance: 0.006416901426495683
# feature: ResponseArea_00-3107, importance: 0.006233244975860119
# feature: ResponseArea_00-3907, importance: 0.006125016094375432
# feature: hour_1, importance: 0.006019352874534109
# feature: hour_10, importance: 0.0059712393261110944
# feature: ResponseArea_00-3604, importance: 0.005948228572155386
# feature: ResponseArea_00-1804, importance: 0.005939485293974556
# feature: ResponseArea_00-0807, importance: 0.005889048895735112
# feature: ResponseArea_00-1602, importance: 0.005729673031610065
# feature: ResponseArea_00-0401, importance: 0.005416797312525224
# feature: hour_6, importance: 0.005380309900462127
# feature: ResponseArea_00-3001, importance: 0.005375996524078056
# feature: hour_5, importance: 0.005312435909497532
# feature: Problem_BOXL- Structure Fire, importance: 0.005151535852649406
# feature: ResponseArea_00-1801, importance: 0.005147848679903145
# feature: ResponseArea_00-2903, importance: 0.005106026190964776
# feature: ResponseArea_00-4001, importance: 0.004923788923630087
# feature: ResponseArea_00-2202, importance: 0.004849960155607605
# feature: ResponseArea_00-0701, importance: 0.004795902742158917
# feature: ResponseArea_00-3204, importance: 0.004692166873787482
# feature: ResponseArea_00-0505, importance: 0.004692101445915321
# feature: Problem_DUMP - Dumpster Fire, importance: 0.004662934785038023
# feature: ResponseArea_00-2401, importance: 0.0045146112494787935
# feature: ResponseArea_00-3404, importance: 0.004484578764686115
# feature: ResponseArea_00-2001, importance: 0.0043678746682259935
# feature: ResponseArea_00-3106, importance: 0.004147068194262018
# feature: ResponseArea_00-3102, importance: 0.004133302848637265
# feature: ResponseArea_00-2101, importance: 0.004075755859412023
# feature: ResponseArea_00-2301, importance: 0.003995698790224273
# feature: ResponseArea_00-2305, importance: 0.003926540350934394
# feature: ResponseArea_00-2702, importance: 0.003898922047684878
# feature: ResponseArea_00-0501, importance: 0.003895598921672465
# feature: ResponseArea_00-2905, importance: 0.0038735091319350304
# feature: ResponseArea_00-2805, importance: 0.0038707129227804823
# feature: ResponseArea_00-2404, importance: 0.003868461005151304
# feature: ResponseArea_00-2801, importance: 0.003831179788739357
# feature: hour_3, importance: 0.0036028223040606754
# feature: ResponseArea_00-2803, importance: 0.003594666807106424
# feature: Problem_BBQ - Unsafe Cooking, importance: 0.003561751469609674
# feature: ResponseArea_00-2910, importance: 0.00355878741315373
# feature: ResponseArea_00-2306, importance: 0.003558702561342826
# feature: ResponseArea_00-2502, importance: 0.00351611454493957
# feature: ResponseArea_00-0804, importance: 0.0035030368907623425
# feature: ResponseArea_00-1803, importance: 0.003474114216090874
# feature: ResponseArea_00-2706, importance: 0.0034109130004474257
# feature: ResponseArea_00-0702, importance: 0.0033715403632158967
# feature: ResponseArea_00-3005, importance: 0.0033565352483501273
# feature: hour_4, importance: 0.0033212235471853724
# feature: ResponseArea_00-0101, importance: 0.0032822072452670034
# feature: ResponseArea_00-1802, importance: 0.003275399240505094
# feature: ResponseArea_00-2601, importance: 0.0031184585647665436
# feature: ResponseArea_00-4502, importance: 0.00309517490002115
# feature: ResponseArea_00-3601, importance: 0.0030709855741682408
# feature: ResponseArea_00-4005, importance: 0.0030412899552299186
# feature: ResponseArea_00-1707, importance: 0.003041211556625507
# feature: ResponseArea_00-0301, importance: 0.00299162754591006
# feature: ResponseArea_00-3403, importance: 0.0029824484215589765
# feature: ResponseArea_00-2607, importance: 0.002962594919896021
# feature: ResponseArea_00-3401, importance: 0.002928285770493569
# feature: ResponseArea_00-3501, importance: 0.0028933201323097283
# feature: ResponseArea_00-2104, importance: 0.0028877487067326124
# feature: ResponseArea_00-0803, importance: 0.0028797715652029965
# feature: ResponseArea_00-4305, importance: 0.002853716477996722
# feature: ResponseArea_00-2303, importance: 0.0028481923413676306
# feature: ResponseArea_00-2807, importance: 0.0028414977549794437
# feature: ResponseArea_00-1603, importance: 0.0027872236826178304
# feature: ResponseArea_00-1706, importance: 0.0027865098070133194
# feature: ResponseArea_00-0801, importance: 0.0027081780395124995
# feature: ResponseArea_00-1705, importance: 0.0026705151290784845
# feature: ResponseArea_00-1404, importance: 0.0026363127078499683
# feature: ResponseArea_00-3801, importance: 0.002619760784757234
# feature: ResponseArea_00-0504, importance: 0.0026151817783657957
# feature: ResponseArea_00-1504, importance: 0.002589442020170965
# feature: ResponseArea_00-3605, importance: 0.002564020095712552
# feature: ResponseArea_00-3502, importance: 0.002554417010788971
# feature: ResponseArea_00-2902, importance: 0.0025084209008997987
# feature: ResponseArea_00-1405, importance: 0.00248860888875395
# feature: ResponseArea_00-1903, importance: 0.002481582932375278
# feature: ResponseArea_00-2005, importance: 0.0024639121452733736
# feature: ResponseArea_00-2606, importance: 0.002449164312545135
# feature: ResponseArea_00-1710, importance: 0.0024035974647753236
# feature: ResponseArea_00-3701, importance: 0.002383293834214263
# feature: ResponseArea_00-17SV, importance: 0.0023602556974906684
# feature: ResponseArea_00-0604, importance: 0.002329830528503944
# feature: ResponseArea_00-4210, importance: 0.002316279916236766
# feature: ResponseArea_00-4201, importance: 0.0023046575672064267
# feature: ResponseArea_00-2806, importance: 0.0022315720815648007
# feature: ResponseArea_00-4504, importance: 0.002205272705204072
# feature: ResponseArea_00-0601, importance: 0.0021020854376424237
# feature: ResponseArea_00-0602, importance: 0.002075936443058064
# feature: ResponseArea_00-3301, importance: 0.002067514905734315
# feature: ResponseArea_00-1407, importance: 0.0020519292651310244
# feature: ResponseArea_00-3809, importance: 0.0019963424176205414
# feature: ResponseArea_00-1401, importance: 0.0019622308526547273
# feature: ResponseArea_00-3201, importance: 0.0019576205492718183
# feature: ResponseArea_00-2501, importance: 0.0019167336363407526
# feature: ResponseArea_00-1502, importance: 0.0019092001642022883
# feature: ResponseArea_00-1505, importance: 0.0018554663369938819
# feature: ResponseArea_00-2906, importance: 0.001784317759002
# feature: ResponseArea_00-3906, importance: 0.001770263013771
# feature: ResponseArea_00-4103, importance: 0.0017504265352744695
# feature: ResponseArea_00-3702, importance: 0.0017097724632474446
# feature: ResponseArea_00-1103, importance: 0.001673853199244752
# feature: ResponseArea_00-3802, importance: 0.0016606668974169935
# feature: ResponseArea_00-4202, importance: 0.0016359548516022442
# feature: ResponseArea_00-1704, importance: 0.0016126320744690892
# feature: ResponseArea_00-1403, importance: 0.0015452674251926837
# feature: ResponseArea_00-4505, importance: 0.0015364132874457679
# feature: ResponseArea_00-0302, importance: 0.0015151643925843138
# feature: ResponseArea_00-2605, importance: 0.0014623551839372737
# feature: ResponseArea_00-3002, importance: 0.0014538422815445577
# feature: ResponseArea_00-2102, importance: 0.0014529856935472506
# feature: ResponseArea_00-4302, importance: 0.0014509414464101966
# feature: ResponseArea_00-1805, importance: 0.0014447199722815514
# feature: ResponseArea_00-4104, importance: 0.0014417147678149026
# feature: ResponseArea_00-3105, importance: 0.0014289159221056891
# feature: ResponseArea_00-3901, importance: 0.0014288263132411485
# feature: ResponseArea_00-4506, importance: 0.001421659076203158
# feature: ResponseArea_00-1712, importance: 0.0014147211988973867
# feature: ResponseArea_00-1101, importance: 0.0014028812162823708
# feature: ResponseArea_00-2704, importance: 0.001402716716766329
# feature: ResponseArea_00-2205, importance: 0.0013871812208283046
# feature: ResponseArea_00-3703, importance: 0.00136645854234971
# feature: ResponseArea_00-2808, importance: 0.0013655623096613836
# feature: ResponseArea_00-4105, importance: 0.001363170123966725
# feature: ResponseArea_00-2004, importance: 0.001345958267160019
# feature: ResponseArea_00-3003, importance: 0.0013227761137877163
# feature: ResponseArea_00-0502, importance: 0.0013193549727650183
# feature: ResponseArea_00-4203, importance: 0.0013067865385046709
# feature: ResponseArea_00-1905, importance: 0.0012894129162940705
# feature: ResponseArea_00-4004, importance: 0.0012784201437586662
# feature: ResponseArea_00-0070, importance: 0.001262575105726737
# feature: ResponseArea_00-0603, importance: 0.0012478096840766717
# feature: ResponseArea_00-3101, importance: 0.0012468322829183721
# feature: ResponseArea_00-0203, importance: 0.001233245995387614
# feature: ResponseArea_00-1406, importance: 0.0012259869103435188
# feature: ResponseArea_00-3808, importance: 0.0012126898070426596
# feature: ResponseArea_00-0402, importance: 0.001197662143585396
# feature: ResponseArea_00-3606, importance: 0.0011955151568672035
# feature: ResponseArea_00-4401, importance: 0.001180152659867031
# feature: ResponseArea_00-1204, importance: 0.00116650481311003
# feature: ResponseArea_00-1708, importance: 0.0011406490932342488
# feature: ResponseArea_00-3610, importance: 0.0011176399809055527
# feature: ResponseArea_00-3608, importance: 0.0011108180681070532
# feature: ResponseArea_00-1701, importance: 0.0010981139669396767
# feature: ResponseArea_00-2608, importance: 0.0010876052667034416
# feature: ResponseArea_00-4002, importance: 0.001066680723116989
# feature: ResponseArea_00-2503, importance: 0.0010555350739984274
# feature: ResponseArea_00-4101, importance: 0.0010380677845045951
# feature: ResponseArea_00-0102, importance: 0.0010125288006426112
# feature: ResponseArea_00-4003, importance: 0.0009988580599102847
# feature: ResponseArea_00-2002, importance: 0.0009910350117780416
# feature: ResponseArea_00-0806, importance: 0.0009789592017153416
# feature: ResponseArea_00-2705, importance: 0.0009756827729752737
# feature: ResponseArea_00-2907, importance: 0.0009589286654079156
# feature: ResponseArea_00-1601, importance: 0.0009507862943323095
# feature: ResponseArea_00-3810, importance: 0.0009223090309717009
# feature: ResponseArea_00-3209, importance: 0.0008984970235805783
# feature: ResponseArea_00-0202, importance: 0.0008947290890081087
# feature: ResponseArea_00-4403, importance: 0.0008674465812643729
# feature: ResponseArea_00-1003, importance: 0.0008458736348017408
# feature: Problem_BRSHL - Brush Alarm / Light, importance: 0.0008394771593756211
# feature: ResponseArea_00-4006, importance: 0.0008037343031800234
# feature: ResponseArea_00-4102, importance: 0.0007965386452688939
# feature: ResponseArea_00-2604, importance: 0.0007953267183453157
# feature: ResponseArea_00-1709, importance: 0.0007790232561590846
# feature: ResponseArea_00-0805, importance: 0.0007708856661893919
# feature: ResponseArea_00-3004, importance: 0.0007609094485417614
# feature: ResponseArea_00-1605, importance: 0.0007605905690249066
# feature: ResponseArea_00-0201, importance: 0.0007446070072757618
# feature: ResponseArea_00-1604, importance: 0.0007227993645889407
# feature: ResponseArea_00-2804, importance: 0.0007014420885256842
# feature: ResponseArea_00-2204, importance: 0.0006942576546394116
# feature: ResponseArea_00-1104, importance: 0.0006773395528669397
# feature: ResponseArea_00-2006, importance: 0.0006392796252295667
# feature: ResponseArea_00-3804, importance: 0.0006252865564873357
# feature: ResponseArea_00-2103, importance: 0.0005840228008158008
# feature: ResponseArea_00-1102, importance: 0.0005695757996597941
# feature: ResponseArea_00-1702, importance: 0.0005411156996549746
# feature: ResponseArea_00-2901, importance: 0.00048468450803560846
# feature: ResponseArea_00-2201, importance: 0.00048263659571917445
# feature: ResponseArea_00-1206, importance: 0.0004428714193216092
# feature: ResponseArea_00-1503, importance: 0.00043649548762328996
# feature: ResponseArea_00-0903, importance: 0.00037842513685339894
# feature: ResponseArea_00-2206, importance: 0.0003730861811772603
# feature: ResponseArea_00-0303, importance: 0.00035225394860145126
# feature: Problem_BOX -Structure Fire, importance: 0.00032833140612910627
# feature: ResponseArea_00-0902, importance: 0.000310082478866839
# feature: ResponseArea_00-1205, importance: 0.00030083383965752675
# feature: ResponseArea_00-3503, importance: 0.00028797866461458823
# feature: ResponseArea_00-4404, importance: 0.0002863659707081815
# feature: ResponseArea_00-2203, importance: 0.00027367436718393566
# feature: ResponseArea_00-1901, importance: 0.00026934320387638806
# feature: ResponseArea_00-1703, importance: 0.0002529883173498314
# feature: ResponseArea_00-4204, importance: 0.0002401400564996309
# feature: ResponseArea_00-3304, importance: 0.00023516940947015765
# feature: ResponseArea_00-1203, importance: 0.00022539801077135123
# feature: ResponseArea_00-3908, importance: 0.00021004543305986812
# feature: ResponseArea_00-1402, importance: 0.00020967577293835122
# feature: ResponseArea_00-1001, importance: 0.0002075564633525933
# feature: ResponseArea_00-1002, importance: 0.00020642470588147114
# feature: ResponseArea_00-1201, importance: 0.00020465236007554012
# feature: ResponseArea_00-1606, importance: 0.00020343389182011395
# feature: ResponseArea_00-0901, importance: 0.0001974050957808234
# feature: ResponseArea_00-0802, importance: 0.0001964182971387521
# feature: ResponseArea_00-2504, importance: 0.00018773987105235554
# feature: ResponseArea_00-1501, importance: 0.000158402429988432
# feature: ResponseArea_00-0060, importance: 0.00015565703720817585
# feature: ResponseArea_00-3202, importance: 0.00015264159630890256
# feature: ResponseArea_00-4107, importance: 0.00012384417330557157
# feature: ResponseArea_00-3203, importance: 0.00010888409096164908
# feature: ResponseArea_00-3402, importance: 0.00010734135807040585
# feature: ResponseArea_00-2701, importance: 9.484989378460156e-05
# feature: ResponseArea_00-1202, importance: 8.76672117261303e-05
# feature: ResponseArea_00-4503, importance: 6.440148424181828e-05
# feature: ResponseArea_00-3103, importance: 6.180666524275578e-05
# feature: ResponseArea_00-4501, importance: 4.4349488611706886e-05
# feature: ResponseArea_00-3303, importance: 3.788987915893809e-05
# feature: ResponseArea_00-3507, importance: 3.3012250081755165e-05
# feature: ResponseArea_00-3400, importance: 3.090902554843965e-05
# feature: ResponseArea_00-4303, importance: 3.0185954014187327e-05
# feature: ResponseArea_00-27SV, importance: 2.94620458743329e-05
# feature: ResponseArea_00-3902, importance: 2.701270328778214e-05
# feature: ResponseArea_00-3207, importance: 1.9947786980824485e-05
# feature: ResponseArea_00-3505, importance: 1.8147319580429077e-05
# feature: ResponseArea_00-4301, importance: 1.551452786532988e-05
# feature: ResponseArea_00-1902, importance: 1.3161153670749546e-05
# feature: ResponseArea_00-3508, importance: 1.1650238647982102e-05
# feature: ResponseArea_00-2302, importance: 1.1560541771981669e-05
# feature: ResponseArea_00-3205, importance: 1.0013717397712445e-05
# feature: ResponseArea_00-3904, importance: 8.860377425392936e-06
# feature: ResponseArea_00-0503, importance: 5.7196566914421455e-06
# feature: ResponseArea_00-1904, importance: 5.526134293903316e-06
# feature: ResponseArea_00-4402, importance: 3.3728525059485675e-06
# feature: ResponseArea_00-0040, importance: 1.3184158678648651e-06
# feature: ResponseArea_00-2611, importance: 6.217524048479964e-07
# feature: ResponseArea_00-4205, importance: 1.4004878955955064e-07
# feature: ResponseArea_00-2003, importance: 0.0
# feature: ResponseArea_00-2610, importance: 0.0
# feature: ResponseArea_00-3104, importance: 0.0
# feature: ResponseArea_00-4405, importance: 0.0
# Accuracy: 0.9778846153846154
# Saving figure Feature Importances Predicting late_response

# %% [markdown]
# ## Run linear regression and logistic regression on days of week and problem types

# %%
# Read in the data
def read_data():
    df = pd.read_csv(os.path.join('..', settings.PROCESSED_DIR, "all_years_with_RT-and-PT.csv"))
    return df

def limit_time_period(df):
    df = df[df['CalendarYear'] >= settings.YEARS_OF_ANALYSES]
    return df

# Fits a linear model using features and 'Response Time (m)' ratings specified here (not set in the settings.py script)
# Prints the summary page to show coefficients, p-values, and R squared
def create_summary_linear(df):
    lr = LinearRegression()
    predictors = ['day_of_week_0', 'day_of_week_1', 'day_of_week_2','day_of_week_3', 'day_of_week_4', 'day_of_week_5', 'Problem_AUTO - Auto Fire', 'Problem_BBQ - Unsafe Cooking', 'Problem_BOX -Structure Fire', 'Problem_BOXL- Structure Fire',  'Problem_DUMP - Dumpster Fire', 'Problem_ELEC - Electrical Fire', 'Problem_GRASS - Small Grass Fire','Problem_TRASH - Trash Fire']
    lr.fit(df[predictors], df['Response Time (m)'])

    X = df[predictors]
    X2 = sm.add_constant(X)
    est = sm.OLS(df['Response Time (m)'], X2)
    est2 = est.fit()
    print(est2.summary())
    pass

# Fits a linear model using features and 'late_response' specified here (not set in the settings.py script)
# Prints the summary page to show coefficients, p-values, and R squared
def create_summary_logistic(df):
    # import chisqprob to prevent error as noted in https://github.com/statsmodels/statsmodels/issues/3931
    from scipy import stats
    stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)
    lr = LogisticRegression()
    # omits to put 'day_of_week_6' or 'Problem_BRSHL - Brush Alarm / Light' in the model as these will be the constants
    predictors = ['day_of_week_0', 'day_of_week_1', 'day_of_week_2','day_of_week_3', 'day_of_week_4', 'day_of_week_5', 'Problem_AUTO - Auto Fire', 'Problem_BBQ - Unsafe Cooking', 'Problem_BOX -Structure Fire', 'Problem_BOXL- Structure Fire',  'Problem_DUMP - Dumpster Fire', 'Problem_ELEC - Electrical Fire', 'Problem_GRASS - Small Grass Fire','Problem_TRASH - Trash Fire']
    lr.fit(df[predictors], df['late_response'])

    X = df[predictors]
    X2 = sm.add_constant(X)
    est = sm.Logit(df['late_response'], X2)
    est2 = est.fit()
    print(est2.summary())

# %%
df = read_data()
create_summary_linear(df)
create_summary_logistic(df)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Response Time (m)   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     4.065
# Date:                Fri, 09 Feb 2018   Prob (F-statistic):           4.40e-07
# Time:                        15:03:58   Log-Likelihood:                -15841.
# No. Observations:                6240   AIC:                         3.171e+04
# Df Residuals:                    6225   BIC:                         3.181e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                5.1274      0.752      6.818      0.000       3.653       6.602
# day_of_week_0                        0.1331      0.144      0.924      0.355      -0.149       0.415
# day_of_week_1                        0.1791      0.145      1.238      0.216      -0.105       0.463
# day_of_week_2                        0.0788      0.149      0.529      0.597      -0.213       0.371
# day_of_week_3                        0.1427      0.145      0.982      0.326      -0.142       0.427
# day_of_week_4                       -0.0027      0.146     -0.018      0.985      -0.288       0.283
# day_of_week_5                        0.0275      0.144      0.191      0.849      -0.255       0.310
# Problem_AUTO - Auto Fire             0.6052      0.749      0.808      0.419      -0.863       2.074
# Problem_BBQ - Unsafe Cooking         0.7454      0.800      0.932      0.351      -0.822       2.313
# Problem_BOX -Structure Fire          0.6630      1.316      0.504      0.614      -1.916       3.242
# Problem_BOXL- Structure Fire         0.1131      0.797      0.142      0.887      -1.449       1.676
# Problem_DUMP - Dumpster Fire        -0.3819      0.759     -0.503      0.615      -1.870       1.106
# Problem_ELEC - Electrical Fire       0.4095      0.749      0.547      0.584      -1.059       1.878
# Problem_GRASS - Small Grass Fire     0.8144      0.752      1.082      0.279      -0.660       2.289
# Problem_TRASH - Trash Fire           0.3330      0.749      0.445      0.656      -1.134       1.801
# ==============================================================================
# Omnibus:                     8288.977   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3202345.832
# Skew:                           7.260   Prob(JB):                         0.00
# Kurtosis:                     113.027   Cond. No.                         67.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimization terminated successfully.
#          Current function value: 0.310196
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          late_response   No. Observations:                 6240
# Model:                          Logit   Df Residuals:                     6225
# Method:                           MLE   Df Model:                           14
# Date:                Fri, 09 Feb 2018   Pseudo R-squ.:                 0.01559
# Time:                        15:03:58   Log-Likelihood:                -1935.6
# converged:                       True   LL-Null:                       -1966.3
#                                         LLR p-value:                 6.862e-08
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                               -2.7822      1.038     -2.680      0.007      -4.817      -0.747
# day_of_week_0                        0.0356      0.161      0.222      0.824      -0.279       0.350
# day_of_week_1                        0.0530      0.161      0.329      0.742      -0.262       0.368
# day_of_week_2                        0.0120      0.167      0.072      0.942      -0.314       0.339
# day_of_week_3                        0.0686      0.161      0.425      0.671      -0.248       0.385
# day_of_week_4                        0.0102      0.163      0.063      0.950      -0.310       0.330
# day_of_week_5                       -0.1281      0.167     -0.767      0.443      -0.455       0.199
# Problem_AUTO - Auto Fire             0.6900      1.035      0.667      0.505      -1.339       2.719
# Problem_BBQ - Unsafe Cooking         0.8589      1.071      0.802      0.422      -1.240       2.958
# Problem_BOX -Structure Fire          0.8475      1.486      0.570      0.568      -2.064       3.759
# Problem_BOXL- Structure Fire         0.0080      1.103      0.007      0.994      -2.154       2.170
# Problem_DUMP - Dumpster Fire        -0.5642      1.065     -0.530      0.596      -2.651       1.522
# Problem_ELEC - Electrical Fire       0.4831      1.035      0.467      0.641      -1.546       2.512
# Problem_GRASS - Small Grass Fire     0.9965      1.036      0.962      0.336      -1.035       3.027
# Problem_TRASH - Trash Fire           0.3059      1.036      0.295      0.768      -1.724       2.336
# ====================================================================================================
# /Users/owentemple/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
